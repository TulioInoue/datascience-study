# %% [markdown]
# ## 1) Importar bibliotecas

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2) Importar base de dados

# %%
df_train = pd.read_csv("./dados/train_linear.csv")
df_test = pd.read_csv("./dados/test_linear.csv")

# %%
df_train.head(2)
# Out:
#           x         y  class
# 0  1.146728  2.233629      0
# 1  3.676886  4.520687      0

# %%
df_test.head(2)
# Out:
#           x         y  class
# 0  2.684292  3.867108      0
# 1  2.707883  4.002614      0

# %%
fig, ax = plt.subplots()

ax.scatter(x = df_train["x"], y = df_train["y"], c = df_train["class"], edgecolors = "#000")
ax.set_title("Distribuição dos pontos classificados.")

plt.show()

# %% [markdown]
# Aleatorizar <code>df_train</code> porque é sempre bom suspeitar de ordenação.

# %%
df_train_resampled = df_train.sample(frac=1, random_state=1).reset_index(drop = True)

X = df_train_resampled[["x", "y"]].values
y = df_train_resampled["class"].values

print(X)
print(y)
# Out:
# [[ 2.7073744   3.9035508 ]
#  [ 3.47114172  4.29469518]
#  [ 0.44076541  1.5755177 ]
#  ...
#  [ 0.43028835 -0.80828008]
#  [ 3.71582209  4.50535384]
#  [ 1.63346652  2.76305651]]
# [0 0 0 ... 1 0 0]

# %% [markdown]
# ## 3) Criando rede neural

# %% [markdown]
# ### 3.1) Definindo rede neural:
#
# <p>A princípio, recomenda-se que a primeira camada de <code>Input</code> seja o mesmo que a dimensão y da base de dados <code>X</code>.
#
# Layers que serão definidos nas <q>camadas ocultas</q> poderão ter um quantidade de <code>units</code> variável de acordo com o problema, porém, sua função de ativação deve ser definida segundo o indicado em <code>tensorflow.ipynb</code>.
#
# Na última camada - que também é um <code>Dense</code> -, a quantidade em <code>units</code> deve ser a mesma que a quantidade de classes a serem definidas. Por sua vez, a função de ativação desta etapa deve ser coerente com o que se está tentando demonstrar.</p>

# %%
X.shape
# Out:
# (4000, 2)

# %%
model = tf.keras.Sequential([
    # Isto vem de X.shape (4000, 2) -> 2:
    tf.keras.Input(shape=(2,)),
    # units é testável, mas ReLU é recomendável para RNNs no geral:
    tf.keras.layers.Dense(units = 4, activation = "relu"),
    # units = 2 porque a quantidade de classes são 2 e
    # activation = "sigmoid" porque estamos lidando com binário (mas poderia ser softmax):
    tf.keras.layers.Dense(units = 2, activation = "sigmoid")
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22 (88.00 B)
#  Trainable params: 22 (88.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 3.2) Definindo parâmetros otimizadores e de aprendizado:
#
# 1. **Definição do Otimizador**: o otimizador é o algoritmo usado para atualizar os pesos da rede para minimizar a função de custo (ou perda). Alguns exemplos de otimizadores incluem Gradiente Descendente Estocástico (SGD), Adam, e RMSprop.
#
# 2. **Definição da Função de Custo**: A função de custo (ou função de perda) mede o quão bem o modelo está performando nos dados de treinamento. O objetivo é minimizar essa função para "treinar" o modelo. Exemplos de funções de custo incluem entropia cruzada categórica para classificação e erro quadrático médio para regressão.
#
# 3. **Definição das Métricas**: As métricas são usadas para monitorar o desempenho do modelo durante o treinamento e a validação. Elas não são usadas durante o treinamento para atualizar o modelo, mas são úteis para avaliar o desempenho do modelo. Exemplos de métricas incluem acurácia, precisão, recall, entre outras.

# %%
# Por padrão, Adam é sempre o mais utilizado:
optimizer = tf.keras.optimizers.Adam()

loss = tf.keras.losses.SparseCategoricalCrossentropy()

metric = tf.keras.metrics.SparseCategoricalAccuracy()

model.compile(
    optimizer = optimizer,
    loss = loss,
    metrics = [metric]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### 3.3) Definindo parada:
#
# <p>Definir e configurar uma parada é importante não só porque pode economizar recursos, como também pode ajudar a determinar onde o modelo está realmente parando de progredir - se é que isso ocorre.</p>

# %%
model_stopping = tf.keras.callbacks.EarlyStopping(
    min_delta = 10**(-3),
    patience = 5,
    verbose = 1
)

history = model.fit(
    X, y,
    epochs = 100,
    batch_size = 2**5,
    validation_split = 0.2,
    callbacks = [model_stopping]
)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6441 - sparse_categorical_accuracy: 0.7344 - val_loss: 0.5140 - val_sparse_categorical_accuracy: 0.9862
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4969 - sparse_categorical_accuracy: 0.9856 - val_loss: 0.4712 - val_sparse_categorical_accuracy: 0.9762
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4509 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.9937
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4014 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.3786 - val_sparse_categorical_accuracy: 0.9975
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3524 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.3282 - val_sparse_categorical_accuracy: 0.9925
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2808 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.2007 - val_sparse_categorical_accuracy: 0.9875
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1578 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.1320 - val_sparse_categorical_accuracy: 0.9937
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1110 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0972 - val_sparse_categorical_accuracy: 0.9975
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0747 - val_sparse_categorical_accuracy: 0.9987
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0657 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0597 - val_sparse_categorical_accuracy: 0.9987
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0488 - val_sparse_categorical_accuracy: 0.9987
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0408 - val_sparse_categorical_accuracy: 0.9987
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0345 - val_sparse_categorical_accuracy: 0.9987
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0295 - val_sparse_categorical_accuracy: 0.9987
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0275 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0255 - val_sparse_categorical_accuracy: 0.9987
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 1.0000
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0212 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0197 - val_sparse_categorical_accuracy: 1.0000
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 1.0000
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0156 - val_sparse_categorical_accuracy: 1.0000
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0151 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 1.0000
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0136 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0126 - val_sparse_categorical_accuracy: 1.0000
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0114 - val_sparse_categorical_accuracy: 1.0000
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0103 - val_sparse_categorical_accuracy: 1.0000
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0102 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0094 - val_sparse_categorical_accuracy: 1.0000
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0093 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0086 - val_sparse_categorical_accuracy: 1.0000
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0078 - val_sparse_categorical_accuracy: 1.0000
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0072 - val_sparse_categorical_accuracy: 1.0000
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 1.0000
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0061 - val_sparse_categorical_accuracy: 1.0000
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0056 - val_sparse_categorical_accuracy: 1.0000
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0052 - val_sparse_categorical_accuracy: 1.0000
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0048 - val_sparse_categorical_accuracy: 1.0000
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0045 - val_sparse_categorical_accuracy: 1.0000
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0041 - val_sparse_categorical_accuracy: 1.0000
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0037 - val_sparse_categorical_accuracy: 1.0000
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 1.0000
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 1.0000
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 1.0000
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0020 - val_sparse_categorical_accuracy: 1.0000
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0019 - val_sparse_categorical_accuracy: 1.0000
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0017 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0016 - val_sparse_categorical_accuracy: 1.0000
# Epoch 42: early stopping

# %% [markdown]
# ### 3.4) Mostrando evolução:

# %%
fig, ax = plt.subplots()

ax.plot(history.epoch, history.history["loss"], "C0", label = "loss")
ax.plot(history.epoch, history.history["val_loss"], "C1", label = "val_loss")

ax.set_title("Linha do tempo (epochs) do valor loss.")

plt.legend()
plt.show()

# %% [markdown]
# ## 4) Testando modelo

# %%
X_test = df_test[["x", "y"]].values
y_test = df_test[["class"]].values

prediction = model.predict(
    X_test
)

print(prediction)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[0.9903863  0.00937472]
#  [0.9920545  0.00809422]
#  [0.99003094 0.00949771]
#  ...
#  [0.01185169 0.9984795 ]
#  [0.01546578 0.99878573]
#  [0.01261411 0.9960702 ]]
